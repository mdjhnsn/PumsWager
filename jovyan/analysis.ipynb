# %%
# %matplotlib inline

import random
import joblib
import shap
import pprint
import numpy as np
import pandas as pd
import seaborn as sns
import xgboost as xgb
import matplotlib.pyplot as plt
import sklearn

from pymongo import MongoClient
from sklearn.model_selection import train_test_split

pd.options.display.float_format = '{:.4f}'.format

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client.pums18

# %%
df0 = pd.DataFrame(list(db.loc.find({})))

# %%
df0.shape
# Out:
# (2351, 5)

# %%
states = df0.STATE.unique()
state = random.choice(states)
state
# Out:
# 'MD'

# %%
pumas = pd.DataFrame(list(db.loc.find({"STATE": state})))
puma = random.choice(df0['LOCATION'])
puma
# Out:
# 'Tarrant County (East)--Euless (South & West) & Arlington (North) Cities'

# %%
df = pd.DataFrame(list(db.lab.find({'LOCATION':puma})))

# %%
df.shape
# Out:
# (721, 26)

# %%
sum_weights = df['WGHT'].sum()
sample_size = min(sum_weights, 500000)
sample_size
# Out:
# 80339

# %%
drop_cols = ['WGHT','_id','ADJINC',]
dfs = df.sample(sample_size, weights=df['WGHT'], replace=True).drop(columns=drop_cols)

# %%
features = ['AGE','SCHL','INDP','OCCP','HOURS',]

# %%
group_col = 'SCHOOLING'
plot_val = 'SALARY'
fig, ax = plt.subplots()
for grp in dfs[group_col].unique():
  subset = dfs[dfs[group_col]==grp]
  ax = sns.kdeplot(subset[plot_val].clip(upper=100000),**dict(shade=True,label=grp,alpha=.1))
# Out:
# Dataset has 0 variance; skipping density estimate.
# Dataset has 0 variance; skipping density estimate.
# Dataset has 0 variance; skipping density estimate.
# Dataset has 0 variance; skipping density estimate.

# %%
target = 'SALARY'

# %%
# X = dfs[features]
X = pd.get_dummies(dfs[features], drop_first=True)
y = dfs[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
fig, ax = plt.subplots()
corr = dfs[features].corr()
mask = np.zeros_like(corr)  
mask[np.tril_indices_from(mask)] = True  
sns.heatmap(corr, fmt=".1f", vmin=-1, vmax=1, center=0, annot=True, ax=ax, cmap='RdBu_r', mask=mask)
# Out:
# <AxesSubplot:>

# %%
xgr = xgb.XGBRegressor()

# %%
xgr.fit(X_train, y_train, eval_set=[(X_test, y_test)],)
# Out:
# [0]	validation_0-rmse:42268.05469
# [1]	validation_0-rmse:33097.55469
# [2]	validation_0-rmse:26734.12891
# [3]	validation_0-rmse:22270.70898
# [4]	validation_0-rmse:19349.91797
# [5]	validation_0-rmse:17440.63086
# [6]	validation_0-rmse:15470.34375
# [7]	validation_0-rmse:14477.38281
# [8]	validation_0-rmse:13849.16894
# [9]	validation_0-rmse:13190.19141
# [10]	validation_0-rmse:12772.59668
# [11]	validation_0-rmse:12516.46582
# [12]	validation_0-rmse:12297.58594
# [13]	validation_0-rmse:12095.44531
# [14]	validation_0-rmse:11794.11035
# [15]	validation_0-rmse:11422.95801
# [16]	validation_0-rmse:10813.78906
# [17]	validation_0-rmse:10675.17188
# [18]	validation_0-rmse:10094.06836
# [19]	validation_0-rmse:9937.96289
# [20]	validation_0-rmse:9747.33594
# [21]	validation_0-rmse:9509.89551
# [22]	validation_0-rmse:9287.31348
# [23]	validation_0-rmse:8842.05273
# [24]	validation_0-rmse:8751.96289
# [25]	validation_0-rmse:8535.81348
# [26]	validation_0-rmse:8434.63965
# [27]	validation_0-rmse:8189.56934
# [28]	validation_0-rmse:8021.60205
# [29]	validation_0-rmse:7815.33740
# [30]	validation_0-rmse:7587.40332
# [31]	validation_0-rmse:7288.68359
# [32]	validation_0-rmse:7052.47949
# [33]	validation_0-rmse:6917.56787
# [34]	validation_0-rmse:6801.51709
# [35]	validation_0-rmse:6697.16211
# [36]	validation_0-rmse:6500.32129
# [37]	validation_0-rmse:6387.79248
# [38]	validation_0-rmse:6056.07715
# [39]	validation_0-rmse:5961.90820
# [40]	validation_0-rmse:5697.69189
# [41]	validation_0-rmse:5528.85645
# [42]	validation_0-rmse:5486.00147
# [43]	validation_0-rmse:5408.54346
# [44]	validation_0-rmse:5313.18897
# [45]	validation_0-rmse:5122.20020
# [46]	validation_0-rmse:4972.63281
# [47]	validation_0-rmse:4933.06103
# [48]	validation_0-rmse:4831.65283
# [49]	validation_0-rmse:4599.08154
# [50]	validation_0-rmse:4448.54639
# [51]	validation_0-rmse:4308.59522
# [52]	validation_0-rmse:4232.09277
# [53]	validation_0-rmse:4165.21973
# [54]	validation_0-rmse:4108.45068
# [55]	validation_0-rmse:4045.78980
# [56]	validation_0-rmse:3970.79199
# [57]	validation_0-rmse:3913.07886
# [58]	validation_0-rmse:3837.08887
# [59]	validation_0-rmse:3734.38037
# [60]	validation_0-rmse:3576.08472
# [61]	validation_0-rmse:3445.19556
# [62]	validation_0-rmse:3323.07617
# [63]	validation_0-rmse:3289.67041
# [64]	validation_0-rmse:3208.27637
# [65]	validation_0-rmse:3180.39111
# [66]	validation_0-rmse:3110.29370
# [67]	validation_0-rmse:3040.24658
# [68]	validation_0-rmse:2996.50635
# [69]	validation_0-rmse:2883.49023
# [70]	validation_0-rmse:2841.40088
# [71]	validation_0-rmse:2778.54712
# [72]	validation_0-rmse:2664.01880
# [73]	validation_0-rmse:2649.82422
# [74]	validation_0-rmse:2619.64844
# [75]	validation_0-rmse:2596.29419
# [76]	validation_0-rmse:2468.29932
# [77]	validation_0-rmse:2456.62061
# [78]	validation_0-rmse:2375.77734
# [79]	validation_0-rmse:2350.92895
# [80]	validation_0-rmse:2322.30542
# [81]	validation_0-rmse:2313.96143
# [82]	validation_0-rmse:2301.68555
# [83]	validation_0-rmse:2249.81201
# [84]	validation_0-rmse:2162.89209
# [85]	validation_0-rmse:2095.26489
# [86]	validation_0-rmse:2035.61865
# [87]	validation_0-rmse:2005.02893
# [88]	validation_0-rmse:1999.02978
# [89]	validation_0-rmse:1974.91028
# [90]	validation_0-rmse:1970.67541
# [91]	validation_0-rmse:1926.43579
# [92]	validation_0-rmse:1885.53857
# [93]	validation_0-rmse:1838.93762
# [94]	validation_0-rmse:1814.14795
# [95]	validation_0-rmse:1764.65881
# [96]	validation_0-rmse:1737.71753
# [97]	validation_0-rmse:1713.09729
# [98]	validation_0-rmse:1701.69604
# [99]	validation_0-rmse:1688.76074
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
explainer = shap.TreeExplainer(xgr)

# %%
dfs['PREDICTION'] = pd.Series(explainer.model.predict(X))
dfs['RESIDUAL'] = dfs[target] - dfs.PREDICTION
dfs['ERROR'] = dfs.RESIDUAL / dfs[target]

# %%
# pd.cut(dfs.ERROR, [-np.inf,-1,-0.5,0,0.5,1,np.inf]).value_counts(normalize=True, sort=False)

# %%
dfs.RESIDUAL.hist()
# Out:
# <AxesSubplot:>

# %%
explainer = shap.explainers.Tree(xgr)

# %%
shap_values = explainer(X_test)

# %%
shap.plots.bar(shap_values)

# %%
idx = random.choice(range(1, len(X_test)))
wage = round(y_test.iloc[idx],2)
pred = explainer.model.predict(X_test.iloc[idx]).round(2)

print(f"\t\t\tActual Wage: {wage}")
print(f"\t\t\tModel Prediction: {pred}")

plot_values = shap_values[idx, :], X_test.iloc[idx, :]
# shap.decision_plot(explainer.expected_value, shap_values[idx], features=X_test.columns)
# shap.force_plot(explainer.expected_value, shap_values[idx], features=X_test.columns)
shap.plots.waterfall(shap_values[idx])
X_test.iloc[idx]
# Out:
# 			Actual Wage: 30000
# 			Model Prediction: 29643.41
# AGE        50
# SCHL       16
# INDP     4770
# OCCP     4010
# HOURS      40
# Name: 279, dtype: int64

# %%
# shap.plots.decision(explainer.expected_value, shap_values.values[idx], features=X_test)

# %%
fig, ax = plt.subplots()
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"SCHL"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"AGE"], color=shap_values)

# %%
shap.plots.heatmap(shap_values[idx:idx+1000])

# %%
# fit a GAM model to the data
# import interpret.glassbox
# model_ebm = interpret.glassbox.ExplainableBoostingRegressor()
# model_ebm.fit(X_test, y_test)

# %%
# a simple linear model
# model = sklearn.linear_model.LinearRegression()
# model.fit(X_test, y_test)

# %%
# # compute the SHAP values for the linear model
# X_sample = X_test.sample(1000)
# background = shap.maskers.Independent(X_sample, max_samples=1000)
# explainer = shap.Explainer(model.predict, background)
# shap_values = explainer(X_sample)

# %%
# make a standard partial dependence plot
# sample_ind = 18
# fig,ax = shap.partial_dependence_plot(
#     "OCCP", model.predict, X, model_expected_value=True,
#     feature_expected_value=True, show=False, ice=False,
#     shap_values=shap_values[sample_ind:sample_ind+1,:],
#     shap_value_features=X.iloc[sample_ind:sample_ind+1,:]
# )

# %%
# explain the GAM model with SHAP
# explainer_ebm = shap.Explainer(model_ebm.predict, background)
# shap_values_ebm = explainer_ebm(X_sample)

# %%
# make a standard partial dependence plot with a single SHAP value overlaid
# fig,ax = shap.partial_dependence_plot(
#     "AGE", model_ebm.predict, X, model_expected_value=True,
#     feature_expected_value=True, show=False, ice=False,
#     shap_values=shap_values_ebm[sample_ind:sample_ind+1,:],
#     shap_value_features=X.iloc[sample_ind:sample_ind+1,:]
# )

# %%
# shap.initjs()
# shap.force_plot(explainer.expected_value, shap.sample(shap_values, 100), features=X_test)

# %%
# fig, ax = plt.subplots()

# rpv = residuals.ResidualsPlot(xgr)
# rpv.fit(X_train, y_train)
# rpv.score(X_test, y_test)
# rpv.poof()
# fig.savefig('residuals_plot.png')

# %%
# residuals.prediction_error(xgr, X_test, y_test)
